# %%
# !pip install tabulate
# Out:
# Collecting tabulate
#   Downloading tabulate-0.9.0-py3-none-any.whl.metadata (34 kB)
# Downloading tabulate-0.9.0-py3-none-any.whl (35 kB)
# Installing collected packages: tabulate
# Successfully installed tabulate-0.9.0
#
# [notice] A new release of pip is available: 24.2 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
# Author: 
# Ryan Lee - rlee51@u.rochester.edu
# Kathleen Zhou - kzhou8@u.rochester.edu
# 2/20/2025

import os
import uuid
import pandas as pd
from tabulate import tabulate
from sqlalchemy import create_engine, text

DB_USERNAME = os.getenv("DB_USERNAME")
DB_PASSWORD = os.getenv("DB_PASSWORD")

engine = create_engine('postgresql://{DB_USERNAME}:{DB_PASSWORD}@localhost:5432/motionlab')

laterality_dict = { 'Left': 'L', 'Right': 'R' }

activity = ['Cohort', 'Activity', 'Repetition', 'Time_Period', 'index', 'SubjectID']

final_activity = pd.DataFrame()
final_trial = pd.DataFrame()
final_measurement = pd.DataFrame()

def insert_measurement(engine, df):
    with engine.begin() as conn:
        conn.execute(
            text("""
            INSERT INTO measurement (
                'trial_id', 
                'laterality', 
                'body_part', 
                'movement_type', 
                'measurement_type', 
                'phase', 
                'measurement_value'
            ) 
            VALUES (:val1, :val2, :val3, :val4, :val5, :val6, :val7)
            """),
            [{ 
                "val1": row[df.columns[0]],
                "val2": row[df.columns[1]],
                "val3": row[df.columns[2]], 
                "val4": row[df.columns[3]], 
                "val5": row[df.columns[4]], 
                "val6": row[df.columns[5]],
            } for index, row in df.iterrows()]
        )
    return True

def insert_specific(engine, df):
    with engine.begin() as conn:
        conn.execute(
            text("""
            INSERT INTO measurement (
                'trial_id', 
                'measurement_name', 
                'measurement_value'
            ) 
            VALUES (:val1, :val2, :val3)
            """),
            [{ 
                "val1": row[df.columns[0]],
                "val2": row[df.columns[1]],
                "val3": row[df.columns[2]]
            } for index, row in df.iterrows()]
        )
    return True

def reduce_redundancy(parts):
    """
    Standardize parts to have only one 'Theia' occurrence in the format '<part>_Theia'.
    
    Input: ['HipMomentTheia', 'Theia'] 
    Output: ['HipMoment_Theia']
    
    Input: ['HipMoment', 'TheiaTheia'] 
    Output: ['HipMoment_Theia']
    
    Input: ['HipMoment', 'Theia', 'Theia'] 
    Output: ['HipMoment_Theia']
    
    Input: ['HipMoment', 'Theia', 'Theia', 'ROM', '123']
    Output: ['HipMoment_Theia', 'ROM', '123']
    """
    result = []
    theia_added = False
    base_part = None
    
    for part in parts:
        if "Theia" in part or part == "Theia":
            if theia_added:
                continue
                
            if not result:
                if part == "Theia":
                    base_part = "Theia"
                else:
                    base_part = part.replace("Theia", "")
                    if not base_part:
                        base_part = "Theia" 
                    else:
                        base_part = base_part + "_Theia"
                result.append(base_part)
            else:
                if "_Theia" not in result[-1]:
                    result[-1] = result[-1] + "_Theia"
            
            theia_added = True
        else:
            result.append(part)
    
    return result


def ingest(filepath, engine):
    df = pd.read_excel(filepath, index_col=0)
    df = df.transpose().reset_index()
    row = df.head(1)
    
    shoulder_specific = ['zxy', 'op1', 'op2']
    spine_cohorts= ['SPL', 'SPC', 'SPD']
    shoulder_cohorts=['SHL']

    cohort = row['Cohort'].iloc[0][:3].upper()
    name = row['Activity'].iloc[0]
    lab_id = row['Cohort'].iloc[0][-1:]
    
    repetition = row['Repetition'].iloc[0]
    trial_id = (
        row['index'].iloc[0].strip() + "_" +
        row['Cohort'].iloc[0][:3].strip() + "_" +
        row['Time_Period'].iloc[0].strip() + "_" +
        row['Activity'].iloc[0].strip().replace(" ", "_") + "_" +
        repetition.strip()
    ).upper()
    
    
    measurement_df = pd.DataFrame(columns=['trial_id', 'laterality', 'body_part', 'movement_type', 'measurement_type', 'phase', 'measurement_value'])
    activity_specific = pd.DataFrame(columns=['trial_id', 'measurement_name', 'measurement_value'])

    for index, row in df.iterrows():
        for col in df.columns:
            parts = reduce_redundancy(col.split("_"))
            if parts[0] in laterality_dict:
                if cohort[:3] in spine_cohorts:
                    lat = parts[0][0]
                    body_part = parts[1]
                    movement_type = parts[2]
                    measurement_type = parts[3]
                    phase = parts[4]
                elif cohort[:3] in shoulder_cohorts:
                    lat = parts[0][0]
                    adjusted = False
                    part_indexer = 1
                    body_part = parts[1:-2]
                    while body_part[part_indexer].lower() in shoulder_specific:
                        adjusted = True
                        part_indexer+=1
                    part_indexer-=1
                    if adjusted:
                        body_part = "_".join(body_part[0:part_indexer+1])
                        movement_type = parts[part_indexer+2]
                        measurement_type = parts[part_indexer+3]
                        phase = "_".join(parts[part_indexer+4:])
                    else:
                        body_part = "_".join(body_part[0:1])
                        movement_type = parts[2]
                        measurement_type = parts[3]
                        phase = "_".join(parts[4:])
                
                new_row= {
                    'trial_id': trial_id,
                    'laterality': lat, 
                    'body_part': body_part, 
                    'movement_type': movement_type, 
                    'measurement_type': measurement_type, 
                    'measurement_value': row[col], 
                    'phase': phase
                }
                # print(f"raw: {col}")
                # print(f"formatted: {new_row}")
                measurement_df = pd.concat([measurement_df, pd.DataFrame([new_row])], ignore_index=True)
            elif col not in activity:
                new_row = { 
                    'trial_id': trial_id,
                    'measurement_name': col,
                    'measurement_value': row[col]
                }
                # print(f"raw specific: {col}")
                # print(f"formatted: {new_row}")
                activity_specific = pd.concat([activity_specific, pd.DataFrame([new_row])], ignore_index=True)

    insert_measurement(engine, measurement_df)
    insert_specific(engine, activity_specific)
    print(tabulate(measurement_df, headers='keys', tablefmt='psql'))

def main():
    directory = ["Spine"]
    for d in directory:
        for filename in os.listdir(d):
            print(filename)
            f = os.path.join(d, filename)
            ingest(f, engine)
            break
        break

# %%
main()
# Out:
# C0324Pst03Walk_1_Database_Export.xlsx
# /var/folders/9s/pp2mynj51v9dsggk6b4q08yr0000gn/T/ipykernel_53113/1087245147.py:173: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   activity_specific = pd.concat([activity_specific, pd.DataFrame([new_row])], ignore_index=True)
# /var/folders/9s/pp2mynj51v9dsggk6b4q08yr0000gn/T/ipykernel_53113/1087245147.py:164: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   measurement_df = pd.concat([measurement_df, pd.DataFrame([new_row])], ignore_index=True)
# +------+------------------------+--------------+--------------+-----------------+--------------------+---------+---------------------+
# |      | trial_id               | laterality   | body_part    | movement_type   | measurement_type   | phase   |   measurement_value |
# |------+------------------------+--------------+--------------+-----------------+--------------------+---------+---------------------|
# |    0 | C0324_SPL_PST03_WALK_1 | L            | Ankle        | Dorsi           | Max                | Stance  |        21.188       |
# |    1 | C0324_SPL_PST03_WALK_1 | L            | Ankle        | Plantar         | Max                | Stance  |         5.27604     |
# |    2 | C0324_SPL_PST03_WALK_1 | L            | Ankle        | Dorsi           | ROM                | Stance  |        26.464       |
# |    3 | C0324_SPL_PST03_WALK_1 | L            | Ankle        | Add             | Max                | Stance  |        -3.40055     |
# |    4 | C0324_SPL_PST03_WALK_1 | L            | Ankle        | Add             | Min                | Stance  |       -17.5343      |
# |    5 | C0324_SPL_PST03_WALK_1 | L            | Ankle        | Add             | ROM                | Stance  |        14.1337      |
# |    6 | C0324_SPL_PST03_WALK_1 | L            | Ankle        | Rot             | Max                | Stance  |        39.5617      |
# |    7 | C0324_SPL_PST03_WALK_1 | L            | Ankle        | Rot             | Min                | Stance  |        10.629       |
# |    8 | C0324_SPL_PST03_WALK_1 | L            | Ankle        | Rot             | ROM                | Stance  |        28.9327      |
# |    9 | C0324_SPL_PST03_WALK_1 | L            | Knee         | Ext             | Max                | Stance  |        -1.13939     |
# |   10 | C0324_SPL_PST03_WALK_1 | L            | Knee         | Flex            | Max                | Stance  |        26.6494      |
# |   11 | C0324_SPL_PST03_WALK_1 | L            | Knee         | Flex            | ROM                | Stance  |        25.51        |
# |   12 | C0324_SPL_PST03_WALK_1 | L            | Knee         | Add             | Max                | Stance  |        -6.14619     |
# |   13 | C0324_SPL_PST03_WALK_1 | L            | Knee         | Add             | Min                | Stance  |       -19.0454      |
# |   14 | C0324_SPL_PST03_WALK_1 | L            | Knee         | Add             | ROM                | Stance  |        12.8992      |
# |   15 | C0324_SPL_PST03_WALK_1 | L            | Knee         | Rot             | Max                | Stance  |        11.8547      |
# |   16 | C0324_SPL_PST03_WALK_1 | L            | Knee         | Rot             | Min                | Stance  |         4.21939     |
# |   17 | C0324_SPL_PST03_WALK_1 | L            | Knee         | Rot             | ROM                | Stance  |         7.63533     |
# |   18 | C0324_SPL_PST03_WALK_1 | L            | Hip          | Ext             | Max                | Stance  |        20.7076      |
# |   19 | C0324_SPL_PST03_WALK_1 | L            | Hip          | Flex            | Max                | Stance  |        32.1927      |
# |   20 | C0324_SPL_PST03_WALK_1 | L            | Hip          | Flex            | ROM                | Stance  |        52.9002      |
# |   21 | C0324_SPL_PST03_WALK_1 | L            | Hip          | Add             | Max                | Stance  |        11.9224      |
# |   22 | C0324_SPL_PST03_WALK_1 | L            | Hip          | Add             | Min                | Stance  |        -1.44252     |
# |   23 | C0324_SPL_PST03_WALK_1 | L            | Hip          | Add             | ROM                | Stance  |        13.3649      |
# |   24 | C0324_SPL_PST03_WALK_1 | L            | Hip          | Rot             | Max                | Stance  |       -25.7275      |
# |   25 | C0324_SPL_PST03_WALK_1 | L            | Hip          | Rot             | Min                | Stance  |       -55.9323      |
# |   26 | C0324_SPL_PST03_WALK_1 | L            | Hip          | Rot             | ROM                | Stance  |        30.2049      |
# |   27 | C0324_SPL_PST03_WALK_1 | L            | Pelvis       | AntTilt         | Max                | Stance  |         6.45749     |
# |   28 | C0324_SPL_PST03_WALK_1 | L            | Pelvis       | AntTilt         | Min                | Stance  |         2.62798     |
# |   29 | C0324_SPL_PST03_WALK_1 | L            | Pelvis       | AntTilt         | ROM                | Stance  |         3.82951     |
# |   30 | C0324_SPL_PST03_WALK_1 | L            | Pelvis       | Obliq           | Max                | Stance  |         1.80218     |
# |   31 | C0324_SPL_PST03_WALK_1 | L            | Pelvis       | Obliq           | Min                | Stance  |        -6.00062     |
# |   32 | C0324_SPL_PST03_WALK_1 | L            | Pelvis       | Obliq           | ROM                | Stance  |         7.8028      |
# |   33 | C0324_SPL_PST03_WALK_1 | L            | Pelvis       | Rot             | Max                | Stance  |         6.44299     |
# |   34 | C0324_SPL_PST03_WALK_1 | L            | Pelvis       | Rot             | Min                | Stance  |        -2.88598     |
# |   35 | C0324_SPL_PST03_WALK_1 | L            | Pelvis       | Rot             | ROM                | Stance  |         9.32896     |
# |   36 | C0324_SPL_PST03_WALK_1 | L            | Spine        | Ext             | Max                | Stance  |        -1.65686     |
# |   37 | C0324_SPL_PST03_WALK_1 | L            | Spine        | Flex            | Max                | Stance  |        -6.75351     |
# |   38 | C0324_SPL_PST03_WALK_1 | L            | Spine        | Flex            | ROM                | Stance  |         5.09665     |
# |   39 | C0324_SPL_PST03_WALK_1 | L            | Spine        | Obliq           | Max                | Stance  |         3.03137     |
# |   40 | C0324_SPL_PST03_WALK_1 | L            | Spine        | Obliq           | Min                | Stance  |       -10.7803      |
# |   41 | C0324_SPL_PST03_WALK_1 | L            | Spine        | Obliq           | ROM                | Stance  |        13.8117      |
# |   42 | C0324_SPL_PST03_WALK_1 | L            | Spine        | Rot             | Max                | Stance  |         5.87368     |
# |   43 | C0324_SPL_PST03_WALK_1 | L            | Spine        | Rot             | Min                | Stance  |        -5.93268     |
# |   44 | C0324_SPL_PST03_WALK_1 | L            | Spine        | Rot             | ROM                | Stance  |        11.8064      |
# |   45 | C0324_SPL_PST03_WALK_1 | L            | Thorax       | Ext             | Max                | Stance  |         1.27825     |
# |   46 | C0324_SPL_PST03_WALK_1 | L            | Thorax       | Flex            | Max                | Stance  |        -2.30259     |
# |   47 | C0324_SPL_PST03_WALK_1 | L            | Thorax       | Flex            | ROM                | Stance  |         3.58084     |
# |   48 | C0324_SPL_PST03_WALK_1 | L            | Thorax       | Obliq           | Max                | Stance  |         4.51501     |
# |   49 | C0324_SPL_PST03_WALK_1 | L            | Thorax       | Obliq           | Min                | Stance  |        -1.35819     |
# |   50 | C0324_SPL_PST03_WALK_1 | L            | Thorax       | Obliq           | ROM                | Stance  |         5.8732      |
# |   51 | C0324_SPL_PST03_WALK_1 | L            | Thorax       | Rot             | Max                | Stance  |         3.79949     |
# |   52 | C0324_SPL_PST03_WALK_1 | L            | Thorax       | Rot             | Min                | Stance  |         0.331025    |
# |   53 | C0324_SPL_PST03_WALK_1 | L            | Thorax       | Rot             | ROM                | Stance  |         3.46847     |
# |   54 | C0324_SPL_PST03_WALK_1 | L            | Neck         | Flex            | Max                | Stance  |        10.7944      |
# |   55 | C0324_SPL_PST03_WALK_1 | L            | Neck         | Flex            | Min                | Stance  |         4.38234     |
# |   56 | C0324_SPL_PST03_WALK_1 | L            | Neck         | Flex            | ROM                | Stance  |         6.41207     |
# |   57 | C0324_SPL_PST03_WALK_1 | L            | Neck         | Obliq           | Max                | Stance  |         1.20824     |
# |   58 | C0324_SPL_PST03_WALK_1 | L            | Neck         | Obliq           | Min                | Stance  |        -0.57577     |
# |   59 | C0324_SPL_PST03_WALK_1 | L            | Neck         | Obliq           | ROM                | Stance  |         1.78401     |
# |   60 | C0324_SPL_PST03_WALK_1 | L            | Neck         | Rot             | Max                | Stance  |        -2.95905     |
# |   61 | C0324_SPL_PST03_WALK_1 | L            | Neck         | Rot             | Min                | Stance  |        -7.01421     |
# |   62 | C0324_SPL_PST03_WALK_1 | L            | Neck         | Rot             | ROM                | Stance  |         4.05516     |
# |   63 | C0324_SPL_PST03_WALK_1 | R            | Ankle        | Dorsi           | Max                | Stance  |        23.5013      |
# |   64 | C0324_SPL_PST03_WALK_1 | R            | Ankle        | Plantar         | Max                | Stance  |         4.93342     |
# |   65 | C0324_SPL_PST03_WALK_1 | R            | Ankle        | Dorsi           | ROM                | Stance  |        28.4347      |
# |   66 | C0324_SPL_PST03_WALK_1 | R            | Ankle        | Add             | Max                | Stance  |        -2.69749     |
# |   67 | C0324_SPL_PST03_WALK_1 | R            | Ankle        | Add             | Min                | Stance  |       -11.03        |
# |   68 | C0324_SPL_PST03_WALK_1 | R            | Ankle        | Add             | ROM                | Stance  |         8.33255     |
# |   69 | C0324_SPL_PST03_WALK_1 | R            | Ankle        | Rot             | Max                | Stance  |        28.5546      |
# |   70 | C0324_SPL_PST03_WALK_1 | R            | Ankle        | Rot             | Min                | Stance  |         8.22951     |
# |   71 | C0324_SPL_PST03_WALK_1 | R            | Ankle        | Rot             | ROM                | Stance  |        20.3251      |
# |   72 | C0324_SPL_PST03_WALK_1 | R            | Knee         | Ext             | Max                | Stance  |        -1.30846     |
# |   73 | C0324_SPL_PST03_WALK_1 | R            | Knee         | Flex            | Max                | Stance  |        34.1495      |
# |   74 | C0324_SPL_PST03_WALK_1 | R            | Knee         | Flex            | ROM                | Stance  |        32.841       |
# |   75 | C0324_SPL_PST03_WALK_1 | R            | Knee         | Add             | Max                | Stance  |        -5.97973     |
# |   76 | C0324_SPL_PST03_WALK_1 | R            | Knee         | Add             | Min                | Stance  |       -15.9851      |
# |   77 | C0324_SPL_PST03_WALK_1 | R            | Knee         | Add             | ROM                | Stance  |        10.0054      |
# |   78 | C0324_SPL_PST03_WALK_1 | R            | Knee         | Rot             | Max                | Stance  |         3.27048     |
# |   79 | C0324_SPL_PST03_WALK_1 | R            | Knee         | Rot             | Min                | Stance  |        -0.947277    |
# |   80 | C0324_SPL_PST03_WALK_1 | R            | Knee         | Rot             | ROM                | Stance  |         4.21776     |
# |   81 | C0324_SPL_PST03_WALK_1 | R            | Hip          | Ext             | Max                | Stance  |        16.0759      |
# |   82 | C0324_SPL_PST03_WALK_1 | R            | Hip          | Flex            | Max                | Stance  |        30.1481      |
# |   83 | C0324_SPL_PST03_WALK_1 | R            | Hip          | Flex            | ROM                | Stance  |        46.224       |
# |   84 | C0324_SPL_PST03_WALK_1 | R            | Hip          | Add             | Max                | Stance  |        13.6516      |
# |   85 | C0324_SPL_PST03_WALK_1 | R            | Hip          | Add             | Min                | Stance  |         0.0785509   |
# |   86 | C0324_SPL_PST03_WALK_1 | R            | Hip          | Add             | ROM                | Stance  |        13.573       |
# |   87 | C0324_SPL_PST03_WALK_1 | R            | Hip          | Rot             | Max                | Stance  |       -17.9664      |
# |   88 | C0324_SPL_PST03_WALK_1 | R            | Hip          | Rot             | Min                | Stance  |       -40.5268      |
# |   89 | C0324_SPL_PST03_WALK_1 | R            | Hip          | Rot             | ROM                | Stance  |        22.5604      |
# |   90 | C0324_SPL_PST03_WALK_1 | R            | Pelvis       | AntTilt         | Max                | Stance  |         6.196       |
# |   91 | C0324_SPL_PST03_WALK_1 | R            | Pelvis       | AntTilt         | Min                | Stance  |         1.42714     |
# |   92 | C0324_SPL_PST03_WALK_1 | R            | Pelvis       | AntTilt         | ROM                | Stance  |         4.76886     |
# |   93 | C0324_SPL_PST03_WALK_1 | R            | Pelvis       | Obliq           | Max                | Stance  |         6.72124     |
# |   94 | C0324_SPL_PST03_WALK_1 | R            | Pelvis       | Obliq           | Min                | Stance  |        -1.28315     |
# |   95 | C0324_SPL_PST03_WALK_1 | R            | Pelvis       | Obliq           | ROM                | Stance  |         8.00439     |
# |   96 | C0324_SPL_PST03_WALK_1 | R            | Pelvis       | Rot             | Max                | Stance  |         3.83051     |
# |   97 | C0324_SPL_PST03_WALK_1 | R            | Pelvis       | Rot             | Min                | Stance  |        -6.27652     |
# |   98 | C0324_SPL_PST03_WALK_1 | R            | Pelvis       | Rot             | ROM                | Stance  |        10.107       |
# |   99 | C0324_SPL_PST03_WALK_1 | R            | Spine        | Flex            | Max                | Stance  |        -2.31226     |
# |  100 | C0324_SPL_PST03_WALK_1 | R            | Spine        | Flex            | Min                | Stance  |        -6.20491     |
# |  101 | C0324_SPL_PST03_WALK_1 | R            | Spine        | Flex            | ROM                | Stance  |         3.89266     |
# |  102 | C0324_SPL_PST03_WALK_1 | R            | Spine        | Obliq           | Max                | Stance  |        11.2452      |
# |  103 | C0324_SPL_PST03_WALK_1 | R            | Spine        | Obliq           | Min                | Stance  |        -2.12698     |
# |  104 | C0324_SPL_PST03_WALK_1 | R            | Spine        | Obliq           | ROM                | Stance  |        13.3722      |
# |  105 | C0324_SPL_PST03_WALK_1 | R            | Spine        | Rot             | Max                | Stance  |         6.2686      |
# |  106 | C0324_SPL_PST03_WALK_1 | R            | Spine        | Rot             | Min                | Stance  |        -5.78024     |
# |  107 | C0324_SPL_PST03_WALK_1 | R            | Spine        | Rot             | ROM                | Stance  |        12.0488      |
# |  108 | C0324_SPL_PST03_WALK_1 | R            | Thorax       | Flex            | Max                | Stance  |         1.54723     |
# |  109 | C0324_SPL_PST03_WALK_1 | R            | Thorax       | Flex            | Min                | Stance  |        -3.80753     |
# |  110 | C0324_SPL_PST03_WALK_1 | R            | Thorax       | Flex            | ROM                | Stance  |         5.35476     |
# |  111 | C0324_SPL_PST03_WALK_1 | R            | Thorax       | Obliq           | Max                | Stance  |         0.898946    |
# |  112 | C0324_SPL_PST03_WALK_1 | R            | Thorax       | Obliq           | Min                | Stance  |        -4.36557     |
# |  113 | C0324_SPL_PST03_WALK_1 | R            | Thorax       | Obliq           | ROM                | Stance  |         5.26451     |
# |  114 | C0324_SPL_PST03_WALK_1 | R            | Thorax       | Rot             | Max                | Stance  |         1.22907     |
# |  115 | C0324_SPL_PST03_WALK_1 | R            | Thorax       | Rot             | Min                | Stance  |        -3.10377     |
# |  116 | C0324_SPL_PST03_WALK_1 | R            | Thorax       | Rot             | ROM                | Stance  |         4.33284     |
# |  117 | C0324_SPL_PST03_WALK_1 | R            | Neck         | Flex            | Max                | Stance  |         7.12045     |
# |  118 | C0324_SPL_PST03_WALK_1 | R            | Neck         | Flex            | Min                | Stance  |         4.69701     |
# |  119 | C0324_SPL_PST03_WALK_1 | R            | Neck         | Flex            | ROM                | Stance  |         2.42344     |
# |  120 | C0324_SPL_PST03_WALK_1 | R            | Neck         | Obliq           | Max                | Stance  |         0.600837    |
# |  121 | C0324_SPL_PST03_WALK_1 | R            | Neck         | Obliq           | Min                | Stance  |        -1.28251     |
# |  122 | C0324_SPL_PST03_WALK_1 | R            | Neck         | Obliq           | ROM                | Stance  |         1.88335     |
# |  123 | C0324_SPL_PST03_WALK_1 | R            | Neck         | Rot             | Max                | Stance  |         6.92028     |
# |  124 | C0324_SPL_PST03_WALK_1 | R            | Neck         | Rot             | Min                | Stance  |         3.32346     |
# |  125 | C0324_SPL_PST03_WALK_1 | R            | Neck         | Rot             | ROM                | Stance  |         3.59682     |
# |  126 | C0324_SPL_PST03_WALK_1 | L            | Ankle        | Dorsi           | Max                | Swing   |         8.0945      |
# |  127 | C0324_SPL_PST03_WALK_1 | L            | Ankle        | Plantar         | Max                | Swing   |         8.69355     |
# |  128 | C0324_SPL_PST03_WALK_1 | L            | Ankle        | Dorsi           | ROM                | Swing   |        16.788       |
# |  129 | C0324_SPL_PST03_WALK_1 | L            | Ankle        | Add             | Max                | Swing   |        -0.587863    |
# |  130 | C0324_SPL_PST03_WALK_1 | L            | Ankle        | Add             | Min                | Swing   |       -17.3434      |
# |  131 | C0324_SPL_PST03_WALK_1 | L            | Ankle        | Add             | ROM                | Swing   |        16.7555      |
# |  132 | C0324_SPL_PST03_WALK_1 | L            | Ankle        | Rot             | Max                | Swing   |        39.2745      |
# |  133 | C0324_SPL_PST03_WALK_1 | L            | Ankle        | Rot             | Min                | Swing   |         3.32014     |
# |  134 | C0324_SPL_PST03_WALK_1 | L            | Ankle        | Rot             | ROM                | Swing   |        35.9543      |
# |  135 | C0324_SPL_PST03_WALK_1 | L            | Knee         | Ext             | Max                | Swing   |         0.240258    |
# |  136 | C0324_SPL_PST03_WALK_1 | L            | Knee         | Flex            | Max                | Swing   |        48.6515      |
# |  137 | C0324_SPL_PST03_WALK_1 | L            | Knee         | Flex            | ROM                | Swing   |        48.8918      |
# |  138 | C0324_SPL_PST03_WALK_1 | L            | Knee         | Add             | Max                | Swing   |        -5.92723     |
# |  139 | C0324_SPL_PST03_WALK_1 | L            | Knee         | Add             | Min                | Swing   |       -32.695       |
# |  140 | C0324_SPL_PST03_WALK_1 | L            | Knee         | Add             | ROM                | Swing   |        26.7678      |
# |  141 | C0324_SPL_PST03_WALK_1 | L            | Knee         | Rot             | Max                | Swing   |        20.1475      |
# |  142 | C0324_SPL_PST03_WALK_1 | L            | Knee         | Rot             | Min                | Swing   |         0.440341    |
# |  143 | C0324_SPL_PST03_WALK_1 | L            | Knee         | Rot             | ROM                | Swing   |        19.7072      |
# |  144 | C0324_SPL_PST03_WALK_1 | L            | Hip          | Ext             | Max                | Swing   |        12.5405      |
# |  145 | C0324_SPL_PST03_WALK_1 | L            | Hip          | Flex            | Max                | Swing   |        29.4515      |
# |  146 | C0324_SPL_PST03_WALK_1 | L            | Hip          | Flex            | ROM                | Swing   |        41.992       |
# |  147 | C0324_SPL_PST03_WALK_1 | L            | Hip          | Add             | Max                | Swing   |         5.93663     |
# |  148 | C0324_SPL_PST03_WALK_1 | L            | Hip          | Add             | Min                | Swing   |        -3.1276      |
# |  149 | C0324_SPL_PST03_WALK_1 | L            | Hip          | Add             | ROM                | Swing   |         9.06423     |
# |  150 | C0324_SPL_PST03_WALK_1 | L            | Hip          | Rot             | Max                | Swing   |       -27.4762      |
# |  151 | C0324_SPL_PST03_WALK_1 | L            | Hip          | Rot             | Min                | Swing   |       -53.9716      |
# |  152 | C0324_SPL_PST03_WALK_1 | L            | Hip          | Rot             | ROM                | Swing   |        26.4954      |
# |  153 | C0324_SPL_PST03_WALK_1 | L            | Pelvis       | AntTilt         | Max                | Swing   |         5.55512     |
# |  154 | C0324_SPL_PST03_WALK_1 | L            | Pelvis       | AntTilt         | Min                | Swing   |         1.34958     |
# |  155 | C0324_SPL_PST03_WALK_1 | L            | Pelvis       | AntTilt         | ROM                | Swing   |         4.20554     |
# |  156 | C0324_SPL_PST03_WALK_1 | L            | Pelvis       | Obliq           | Max                | Swing   |         0.497405    |
# |  157 | C0324_SPL_PST03_WALK_1 | L            | Pelvis       | Obliq           | Min                | Swing   |        -6.24706     |
# |  158 | C0324_SPL_PST03_WALK_1 | L            | Pelvis       | Obliq           | ROM                | Swing   |         6.74446     |
# |  159 | C0324_SPL_PST03_WALK_1 | L            | Pelvis       | Rot             | Max                | Swing   |         5.17587     |
# |  160 | C0324_SPL_PST03_WALK_1 | L            | Pelvis       | Rot             | Min                | Swing   |        -1.74352     |
# |  161 | C0324_SPL_PST03_WALK_1 | L            | Pelvis       | Rot             | ROM                | Swing   |         6.91939     |
# |  162 | C0324_SPL_PST03_WALK_1 | L            | Spine        | Ext             | Max                | Swing   |        -2.34759     |
# |  163 | C0324_SPL_PST03_WALK_1 | L            | Spine        | Flex            | Max                | Swing   |        -5.51111     |
# |  164 | C0324_SPL_PST03_WALK_1 | L            | Spine        | Flex            | ROM                | Swing   |         3.16352     |
# |  165 | C0324_SPL_PST03_WALK_1 | L            | Spine        | Obliq           | Max                | Swing   |        -1.61858     |
# |  166 | C0324_SPL_PST03_WALK_1 | L            | Spine        | Obliq           | Min                | Swing   |       -11.2331      |
# |  167 | C0324_SPL_PST03_WALK_1 | L            | Spine        | Obliq           | ROM                | Swing   |         9.61452     |
# |  168 | C0324_SPL_PST03_WALK_1 | L            | Spine        | Rot             | Max                | Swing   |         4.69072     |
# |  169 | C0324_SPL_PST03_WALK_1 | L            | Spine        | Rot             | Min                | Swing   |        -5.20011     |
# |  170 | C0324_SPL_PST03_WALK_1 | L            | Spine        | Rot             | ROM                | Swing   |         9.89083     |
# |  171 | C0324_SPL_PST03_WALK_1 | L            | Thorax       | Ext             | Max                | Swing   |         1.00244     |
# |  172 | C0324_SPL_PST03_WALK_1 | L            | Thorax       | Flex            | Max                | Swing   |        -2.01176     |
# |  173 | C0324_SPL_PST03_WALK_1 | L            | Thorax       | Flex            | ROM                | Swing   |         3.0142      |
# |  174 | C0324_SPL_PST03_WALK_1 | L            | Thorax       | Obliq           | Max                | Swing   |         4.80629     |
# |  175 | C0324_SPL_PST03_WALK_1 | L            | Thorax       | Obliq           | Min                | Swing   |         1.62796     |
# |  176 | C0324_SPL_PST03_WALK_1 | L            | Thorax       | Obliq           | ROM                | Swing   |         3.17833     |
# |  177 | C0324_SPL_PST03_WALK_1 | L            | Thorax       | Rot             | Max                | Swing   |         3.78649     |
# |  178 | C0324_SPL_PST03_WALK_1 | L            | Thorax       | Rot             | Min                | Swing   |        -0.363487    |
# |  179 | C0324_SPL_PST03_WALK_1 | L            | Thorax       | Rot             | ROM                | Swing   |         4.14997     |
# |  180 | C0324_SPL_PST03_WALK_1 | L            | Neck         | Flex            | Max                | Swing   |        10.7944      |
# |  181 | C0324_SPL_PST03_WALK_1 | L            | Neck         | Flex            | Min                | Swing   |         4.38234     |
# |  182 | C0324_SPL_PST03_WALK_1 | L            | Neck         | Flex            | ROM                | Swing   |         6.41207     |
# |  183 | C0324_SPL_PST03_WALK_1 | L            | Neck         | Obliq           | Max                | Swing   |         1.10057     |
# |  184 | C0324_SPL_PST03_WALK_1 | L            | Neck         | Obliq           | Min                | Swing   |         0.142563    |
# |  185 | C0324_SPL_PST03_WALK_1 | L            | Neck         | Obliq           | ROM                | Swing   |         0.958004    |
# |  186 | C0324_SPL_PST03_WALK_1 | L            | Neck         | Rot             | Max                | Swing   |        -2.45219     |
# |  187 | C0324_SPL_PST03_WALK_1 | L            | Neck         | Rot             | Min                | Swing   |        -5.12268     |
# |  188 | C0324_SPL_PST03_WALK_1 | L            | Neck         | Rot             | ROM                | Swing   |         2.67048     |
# |  189 | C0324_SPL_PST03_WALK_1 | R            | Ankle        | Dorsi           | Max                | Swing   |         8.89753     |
# |  190 | C0324_SPL_PST03_WALK_1 | R            | Ankle        | Plantar         | Max                | Swing   |        12.6463      |
# |  191 | C0324_SPL_PST03_WALK_1 | R            | Ankle        | Dorsi           | ROM                | Swing   |        21.5438      |
# |  192 | C0324_SPL_PST03_WALK_1 | R            | Ankle        | Add             | Max                | Swing   |        -3.34206     |
# |  193 | C0324_SPL_PST03_WALK_1 | R            | Ankle        | Add             | Min                | Swing   |       -14.0214      |
# |  194 | C0324_SPL_PST03_WALK_1 | R            | Ankle        | Add             | ROM                | Swing   |        10.6794      |
# |  195 | C0324_SPL_PST03_WALK_1 | R            | Ankle        | Rot             | Max                | Swing   |        34.3189      |
# |  196 | C0324_SPL_PST03_WALK_1 | R            | Ankle        | Rot             | Min                | Swing   |         9.9751      |
# |  197 | C0324_SPL_PST03_WALK_1 | R            | Ankle        | Rot             | ROM                | Swing   |        24.3438      |
# |  198 | C0324_SPL_PST03_WALK_1 | R            | Knee         | Ext             | Max                | Swing   |         2.27475     |
# |  199 | C0324_SPL_PST03_WALK_1 | R            | Knee         | Flex            | Max                | Swing   |        55.325       |
# |  200 | C0324_SPL_PST03_WALK_1 | R            | Knee         | Flex            | ROM                | Swing   |        57.5997      |
# |  201 | C0324_SPL_PST03_WALK_1 | R            | Knee         | Add             | Max                | Swing   |        -2.81721     |
# |  202 | C0324_SPL_PST03_WALK_1 | R            | Knee         | Add             | Min                | Swing   |       -22.359       |
# |  203 | C0324_SPL_PST03_WALK_1 | R            | Knee         | Add             | ROM                | Swing   |        19.5418      |
# |  204 | C0324_SPL_PST03_WALK_1 | R            | Knee         | Rot             | Max                | Swing   |         3.70863     |
# |  205 | C0324_SPL_PST03_WALK_1 | R            | Knee         | Rot             | Min                | Swing   |        -1.3253      |
# |  206 | C0324_SPL_PST03_WALK_1 | R            | Knee         | Rot             | ROM                | Swing   |         5.03393     |
# |  207 | C0324_SPL_PST03_WALK_1 | R            | Hip          | Ext             | Max                | Swing   |        11.2244      |
# |  208 | C0324_SPL_PST03_WALK_1 | R            | Hip          | Flex            | Max                | Swing   |        26.9245      |
# |  209 | C0324_SPL_PST03_WALK_1 | R            | Hip          | Flex            | ROM                | Swing   |        38.1489      |
# |  210 | C0324_SPL_PST03_WALK_1 | R            | Hip          | Add             | Max                | Swing   |         5.6867      |
# |  211 | C0324_SPL_PST03_WALK_1 | R            | Hip          | Add             | Min                | Swing   |        -1.82351     |
# |  212 | C0324_SPL_PST03_WALK_1 | R            | Hip          | Add             | ROM                | Swing   |         7.51022     |
# |  213 | C0324_SPL_PST03_WALK_1 | R            | Hip          | Rot             | Max                | Swing   |       -20.2284      |
# |  214 | C0324_SPL_PST03_WALK_1 | R            | Hip          | Rot             | Min                | Swing   |       -42.2512      |
# |  215 | C0324_SPL_PST03_WALK_1 | R            | Hip          | Rot             | ROM                | Swing   |        22.0228      |
# |  216 | C0324_SPL_PST03_WALK_1 | R            | Pelvis       | AntTilt         | Max                | Swing   |         2.3211      |
# |  217 | C0324_SPL_PST03_WALK_1 | R            | Pelvis       | AntTilt         | Min                | Swing   |         0.455545    |
# |  218 | C0324_SPL_PST03_WALK_1 | R            | Pelvis       | AntTilt         | ROM                | Swing   |         1.86556     |
# |  219 | C0324_SPL_PST03_WALK_1 | R            | Pelvis       | Obliq           | Max                | Swing   |         3.12032     |
# |  220 | C0324_SPL_PST03_WALK_1 | R            | Pelvis       | Obliq           | Min                | Swing   |        -1.60428     |
# |  221 | C0324_SPL_PST03_WALK_1 | R            | Pelvis       | Obliq           | ROM                | Swing   |         4.72459     |
# |  222 | C0324_SPL_PST03_WALK_1 | R            | Pelvis       | Rot             | Max                | Swing   |         1.55183     |
# |  223 | C0324_SPL_PST03_WALK_1 | R            | Pelvis       | Rot             | Min                | Swing   |        -5.54191     |
# |  224 | C0324_SPL_PST03_WALK_1 | R            | Pelvis       | Rot             | ROM                | Swing   |         7.09373     |
# |  225 | C0324_SPL_PST03_WALK_1 | R            | Spine        | Ext             | Max                | Swing   |        -2.34759     |
# |  226 | C0324_SPL_PST03_WALK_1 | R            | Spine        | Flex            | Max                | Swing   |        -5.51111     |
# |  227 | C0324_SPL_PST03_WALK_1 | R            | Spine        | Flex            | ROM                | Swing   |         3.16352     |
# |  228 | C0324_SPL_PST03_WALK_1 | R            | Spine        | Obliq           | Max                | Swing   |         4.53285     |
# |  229 | C0324_SPL_PST03_WALK_1 | R            | Spine        | Obliq           | Min                | Swing   |        -2.7495      |
# |  230 | C0324_SPL_PST03_WALK_1 | R            | Spine        | Obliq           | ROM                | Swing   |         7.28235     |
# |  231 | C0324_SPL_PST03_WALK_1 | R            | Spine        | Rot             | Max                | Swing   |         5.18368     |
# |  232 | C0324_SPL_PST03_WALK_1 | R            | Spine        | Rot             | Min                | Swing   |        -4.95806     |
# |  233 | C0324_SPL_PST03_WALK_1 | R            | Spine        | Rot             | ROM                | Swing   |        10.1417      |
# |  234 | C0324_SPL_PST03_WALK_1 | R            | Thorax       | Ext             | Max                | Swing   |         1.00244     |
# |  235 | C0324_SPL_PST03_WALK_1 | R            | Thorax       | Flex            | Max                | Swing   |        -2.01176     |
# |  236 | C0324_SPL_PST03_WALK_1 | R            | Thorax       | Flex            | ROM                | Swing   |         3.0142      |
# |  237 | C0324_SPL_PST03_WALK_1 | R            | Thorax       | Obliq           | Max                | Swing   |         1.30286     |
# |  238 | C0324_SPL_PST03_WALK_1 | R            | Thorax       | Obliq           | Min                | Swing   |        -2.0226      |
# |  239 | C0324_SPL_PST03_WALK_1 | R            | Thorax       | Obliq           | ROM                | Swing   |         3.32546     |
# |  240 | C0324_SPL_PST03_WALK_1 | R            | Thorax       | Rot             | Max                | Swing   |        -0.503471    |
# |  241 | C0324_SPL_PST03_WALK_1 | R            | Thorax       | Rot             | Min                | Swing   |        -3.8602      |
# |  242 | C0324_SPL_PST03_WALK_1 | R            | Thorax       | Rot             | ROM                | Swing   |         3.35673     |
# |  243 | C0324_SPL_PST03_WALK_1 | R            | Neck         | Flex            | Max                | Swing   |         4.94161     |
# |  244 | C0324_SPL_PST03_WALK_1 | R            | Neck         | Flex            | Min                | Swing   |         3.32081     |
# |  245 | C0324_SPL_PST03_WALK_1 | R            | Neck         | Flex            | ROM                | Swing   |         1.6208      |
# |  246 | C0324_SPL_PST03_WALK_1 | R            | Neck         | Obliq           | Max                | Swing   |         0.727595    |
# |  247 | C0324_SPL_PST03_WALK_1 | R            | Neck         | Obliq           | Min                | Swing   |        -0.879361    |
# |  248 | C0324_SPL_PST03_WALK_1 | R            | Neck         | Obliq           | ROM                | Swing   |         1.60696     |
# |  249 | C0324_SPL_PST03_WALK_1 | R            | Neck         | Rot             | Max                | Swing   |         5.03607     |
# |  250 | C0324_SPL_PST03_WALK_1 | R            | Neck         | Rot             | Min                | Swing   |         2.71307     |
# |  251 | C0324_SPL_PST03_WALK_1 | R            | Neck         | Rot             | ROM                | Swing   |         2.323       |
# |  252 | C0324_SPL_PST03_WALK_1 | L            | Hip          | Flex            | Z                  | RHS     |       -18.5181      |
# |  253 | C0324_SPL_PST03_WALK_1 | L            | Hip          | Add             | Z                  | RHS     |         6.08182     |
# |  254 | C0324_SPL_PST03_WALK_1 | L            | Hip          | Rot             | Z                  | RHS     |       -28.0251      |
# |  255 | C0324_SPL_PST03_WALK_1 | L            | Knee         | Flex            | Z                  | RHS     |         0.987313    |
# |  256 | C0324_SPL_PST03_WALK_1 | L            | Knee         | Add             | Z                  | RHS     |        -7.62506     |
# |  257 | C0324_SPL_PST03_WALK_1 | L            | Knee         | Rot             | Z                  | RHS     |         4.50725     |
# |  258 | C0324_SPL_PST03_WALK_1 | L            | AbsAnkle     | Flex            | Z                  | RHS     |        19.4097      |
# |  259 | C0324_SPL_PST03_WALK_1 | L            | AbsAnkle     | Add             | Z                  | RHS     |         0           |
# |  260 | C0324_SPL_PST03_WALK_1 | L            | AbsAnkle     | Rot             | Z                  | RHS     |         0           |
# |  261 | C0324_SPL_PST03_WALK_1 | L            | Ankle        | Flex            | Z                  | RHS     |        21.9494      |
# |  262 | C0324_SPL_PST03_WALK_1 | L            | Ankle        | Add             | Z                  | RHS     |       -10.5577      |
# |  263 | C0324_SPL_PST03_WALK_1 | L            | Ankle        | Rot             | Z                  | RHS     |        27.2438      |
# |  264 | C0324_SPL_PST03_WALK_1 | R            | Hip          | Flex            | Z                  | RHS     |        28.9898      |
# |  265 | C0324_SPL_PST03_WALK_1 | R            | Hip          | Add             | Z                  | RHS     |         3.55101     |
# |  266 | C0324_SPL_PST03_WALK_1 | R            | Hip          | Rot             | Z                  | RHS     |       -39.5578      |
# |  267 | C0324_SPL_PST03_WALK_1 | R            | Knee         | Flex            | Z                  | RHS     |        -0.715344    |
# |  268 | C0324_SPL_PST03_WALK_1 | R            | Knee         | Add             | Z                  | RHS     |        -4.49618     |
# |  269 | C0324_SPL_PST03_WALK_1 | R            | Knee         | Rot             | Z                  | RHS     |        -0.741825    |
# |  270 | C0324_SPL_PST03_WALK_1 | R            | Ankle        | Flex            | Z                  | RHS     |         7.52804     |
# |  271 | C0324_SPL_PST03_WALK_1 | R            | Ankle        | Add             | Z                  | RHS     |       -12.1295      |
# |  272 | C0324_SPL_PST03_WALK_1 | R            | Ankle        | Rot             | Z                  | RHS     |        30.9204      |
# |  273 | C0324_SPL_PST03_WALK_1 | R            | AbsAnkle     | Flex            | Z                  | RHS     |         6.45327     |
# |  274 | C0324_SPL_PST03_WALK_1 | R            | AbsAnkle     | Add             | Z                  | RHS     |         0           |
# |  275 | C0324_SPL_PST03_WALK_1 | R            | AbsAnkle     | Rot             | Z                  | RHS     |         0           |
# |  276 | C0324_SPL_PST03_WALK_1 | L            | Pelvis       | AntTilt         | Z                  | RHS     |         4.34316     |
# |  277 | C0324_SPL_PST03_WALK_1 | L            | Pelvis       | Obliq           | Z                  | RHS     |        -2.1461      |
# |  278 | C0324_SPL_PST03_WALK_1 | L            | Pelvis       | Rot             | Z                  | RHS     |        -3.01254     |
# |  279 | C0324_SPL_PST03_WALK_1 | R            | Pelvis       | AntTilt         | Z                  | RHS     |         4.34316     |
# |  280 | C0324_SPL_PST03_WALK_1 | R            | Pelvis       | Obliq           | Z                  | RHS     |         2.1461      |
# |  281 | C0324_SPL_PST03_WALK_1 | R            | Pelvis       | Rot             | Z                  | RHS     |         3.01254     |
# |  282 | C0324_SPL_PST03_WALK_1 | L            | FootProgress | Flex            | Z                  | RHS     |       -82.293       |
# |  283 | C0324_SPL_PST03_WALK_1 | L            | FootProgress | Add             | Z                  | RHS     |         4.18008     |
# |  284 | C0324_SPL_PST03_WALK_1 | L            | FootProgress | Rot             | Z                  | RHS     |         2.6686      |
# |  285 | C0324_SPL_PST03_WALK_1 | R            | FootProgress | Flex            | Z                  | RHS     |      -118.891       |
# |  286 | C0324_SPL_PST03_WALK_1 | R            | FootProgress | Add             | Z                  | RHS     |         6.69275     |
# |  287 | C0324_SPL_PST03_WALK_1 | R            | FootProgress | Rot             | Z                  | RHS     |        -5.32784     |
# |  288 | C0324_SPL_PST03_WALK_1 | R            | Neck         | Flex            | Z                  | RHS     |         9.77235     |
# |  289 | C0324_SPL_PST03_WALK_1 | R            | Neck         | Obliq           | Z                  | RHS     |        -1.04666     |
# |  290 | C0324_SPL_PST03_WALK_1 | R            | Neck         | Rot             | Z                  | RHS     |         6.09924     |
# |  291 | C0324_SPL_PST03_WALK_1 | L            | Neck         | Flex            | Z                  | RHS     |         9.77235     |
# |  292 | C0324_SPL_PST03_WALK_1 | L            | Neck         | Obliq           | Z                  | RHS     |         1.04666     |
# |  293 | C0324_SPL_PST03_WALK_1 | L            | Neck         | Rot             | Z                  | RHS     |        -6.09924     |
# |  294 | C0324_SPL_PST03_WALK_1 | R            | Spine        | Flex            | Z                  | RHS     |        -2.74719     |
# |  295 | C0324_SPL_PST03_WALK_1 | R            | Spine        | Obliq           | Z                  | RHS     |         3.80602     |
# |  296 | C0324_SPL_PST03_WALK_1 | R            | Spine        | Rot             | Z                  | RHS     |         5.58454     |
# |  297 | C0324_SPL_PST03_WALK_1 | L            | Spine        | Flex            | Z                  | RHS     |        -2.74719     |
# |  298 | C0324_SPL_PST03_WALK_1 | L            | Spine        | Obliq           | Z                  | RHS     |        -3.80602     |
# |  299 | C0324_SPL_PST03_WALK_1 | L            | Spine        | Rot             | Z                  | RHS     |        -5.58454     |
# |  300 | C0324_SPL_PST03_WALK_1 | L            | Shoulder     | Flex            | Z                  | RHS     |         8.31068     |
# |  301 | C0324_SPL_PST03_WALK_1 | L            | Shoulder     | Add             | Z                  | RHS     |        17.3643      |
# |  302 | C0324_SPL_PST03_WALK_1 | L            | Shoulder     | Rot             | Z                  | RHS     |        24.238       |
# |  303 | C0324_SPL_PST03_WALK_1 | L            | Elbow        | Flex            | Z                  | RHS     |        39.0035      |
# |  304 | C0324_SPL_PST03_WALK_1 | L            | Elbow        | Add             | Z                  | RHS     |         3.97569e-16 |
# |  305 | C0324_SPL_PST03_WALK_1 | L            | Elbow        | Rot             | Z                  | RHS     |         1.63799e-12 |
# |  306 | C0324_SPL_PST03_WALK_1 | L            | Wrist        | Flex            | Z                  | RHS     |        -1.43686     |
# |  307 | C0324_SPL_PST03_WALK_1 | L            | Wrist        | Add             | Z                  | RHS     |        10.8001      |
# |  308 | C0324_SPL_PST03_WALK_1 | L            | Wrist        | Rot             | Z                  | RHS     |       107.051       |
# |  309 | C0324_SPL_PST03_WALK_1 | R            | Shoulder     | Flex            | Z                  | RHS     |       -24.5389      |
# |  310 | C0324_SPL_PST03_WALK_1 | R            | Shoulder     | Add             | Z                  | RHS     |        25.6131      |
# |  311 | C0324_SPL_PST03_WALK_1 | R            | Shoulder     | Rot             | Z                  | RHS     |        33.0997      |
# |  312 | C0324_SPL_PST03_WALK_1 | R            | Elbow        | Flex            | Z                  | RHS     |        34.8214      |
# |  313 | C0324_SPL_PST03_WALK_1 | R            | Elbow        | Add             | Z                  | RHS     |         0           |
# |  314 | C0324_SPL_PST03_WALK_1 | R            | Elbow        | Rot             | Z                  | RHS     |         2.30272e-12 |
# |  315 | C0324_SPL_PST03_WALK_1 | R            | Wrist        | Flex            | Z                  | RHS     |       -11.3794      |
# |  316 | C0324_SPL_PST03_WALK_1 | R            | Wrist        | Add             | Z                  | RHS     |         8.87558     |
# |  317 | C0324_SPL_PST03_WALK_1 | R            | Wrist        | Rot             | Z                  | RHS     |       111.27        |
# |  318 | C0324_SPL_PST03_WALK_1 | R            | Thorax       | Flex            | Z                  | RHS     |         1.42702     |
# |  319 | C0324_SPL_PST03_WALK_1 | R            | Thorax       | Obliq           | Z                  | RHS     |        -1.53099     |
# |  320 | C0324_SPL_PST03_WALK_1 | R            | Thorax       | Rot             | Z                  | RHS     |        -2.64763     |
# |  321 | C0324_SPL_PST03_WALK_1 | L            | Thorax       | Flex            | Z                  | RHS     |         1.42702     |
# |  322 | C0324_SPL_PST03_WALK_1 | L            | Thorax       | Obliq           | Z                  | RHS     |         1.53099     |
# |  323 | C0324_SPL_PST03_WALK_1 | L            | Thorax       | Rot             | Z                  | RHS     |         2.64763     |
# |  324 | C0324_SPL_PST03_WALK_1 | R            | Head         | Flex            | Z                  | RHS     |       -11.2496      |
# |  325 | C0324_SPL_PST03_WALK_1 | R            | Head         | Obliq           | Z                  | RHS     |        -1.96803     |
# |  326 | C0324_SPL_PST03_WALK_1 | R            | Head         | Rot             | Z                  | RHS     |        -8.53573     |
# |  327 | C0324_SPL_PST03_WALK_1 | L            | Head         | Flex            | Z                  | RHS     |       -11.2496      |
# |  328 | C0324_SPL_PST03_WALK_1 | L            | Head         | Obliq           | Z                  | RHS     |         1.96803     |
# |  329 | C0324_SPL_PST03_WALK_1 | L            | Head         | Rot             | Z                  | RHS     |         8.53573     |
# |  330 | C0324_SPL_PST03_WALK_1 | L            | Hip          | Flex            | Max                | RHTLH   |        32.7617      |
# |  331 | C0324_SPL_PST03_WALK_1 | L            | Hip          | Flex            | Min                | RHTLH   |       -24.5441      |
# |  332 | C0324_SPL_PST03_WALK_1 | L            | Hip          | Flex            | ROM                | RHTLH   |        57.3058      |
# |  333 | C0324_SPL_PST03_WALK_1 | L            | Hip          | Add             | Max                | RHTLH   |         8.26596     |
# |  334 | C0324_SPL_PST03_WALK_1 | L            | Hip          | Add             | Min                | RHTLH   |        -6.90184     |
# |  335 | C0324_SPL_PST03_WALK_1 | L            | Hip          | Add             | ROM                | RHTLH   |        15.1678      |
# |  336 | C0324_SPL_PST03_WALK_1 | L            | Hip          | Rot             | Max                | RHTLH   |       -27.78        |
# |  337 | C0324_SPL_PST03_WALK_1 | L            | Hip          | Rot             | Min                | RHTLH   |       -55.4401      |
# |  338 | C0324_SPL_PST03_WALK_1 | L            | Hip          | Rot             | ROM                | RHTLH   |        27.6601      |
# |  339 | C0324_SPL_PST03_WALK_1 | L            | Knee         | Flex            | Max                | RHTLH   |        52.1046      |
# |  340 | C0324_SPL_PST03_WALK_1 | L            | Knee         | Flex            | Min                | RHTLH   |        -2.32246     |
# |  341 | C0324_SPL_PST03_WALK_1 | L            | Knee         | Flex            | ROM                | RHTLH   |        54.4271      |
# |  342 | C0324_SPL_PST03_WALK_1 | L            | Knee         | Add             | Max                | RHTLH   |        -3.13778     |
# |  343 | C0324_SPL_PST03_WALK_1 | L            | Knee         | Add             | Min                | RHTLH   |       -37.2469      |
# |  344 | C0324_SPL_PST03_WALK_1 | L            | Knee         | Add             | ROM                | RHTLH   |        34.1091      |
# ...
# | 2241 | C0324_SPL_PST03_WALK_1 | L            | Neck         | Flex            | Max                | RMTLH   |        10.7259      |
# | 2242 | C0324_SPL_PST03_WALK_1 | L            | Neck         | Flex            | Min                | RMTLH   |        10.5099      |
# | 2243 | C0324_SPL_PST03_WALK_1 | L            | Neck         | Flex            | ROM                | RMTLH   |         0.216       |
# | 2244 | C0324_SPL_PST03_WALK_1 | L            | Neck         | Obliq           | Max                | RMTLH   |         1.13715     |
# | 2245 | C0324_SPL_PST03_WALK_1 | L            | Neck         | Obliq           | Min                | RMTLH   |         0.213017    |
# | 2246 | C0324_SPL_PST03_WALK_1 | L            | Neck         | Obliq           | ROM                | RMTLH   |         0.924133    |
# | 2247 | C0324_SPL_PST03_WALK_1 | L            | Neck         | Rot             | Max                | RMTLH   |        -5.66736     |
# | 2248 | C0324_SPL_PST03_WALK_1 | L            | Neck         | Rot             | Min                | RMTLH   |        -6.80954     |
# | 2249 | C0324_SPL_PST03_WALK_1 | L            | Neck         | Rot             | ROM                | RMTLH   |         1.14218     |
# | 2250 | C0324_SPL_PST03_WALK_1 | R            | Spine        | Flex            | Max                | RMTLH   |        -3.91389     |
# | 2251 | C0324_SPL_PST03_WALK_1 | R            | Spine        | Flex            | Min                | RMTLH   |        -5.90746     |
# | 2252 | C0324_SPL_PST03_WALK_1 | R            | Spine        | Flex            | ROM                | RMTLH   |         1.99357     |
# | 2253 | C0324_SPL_PST03_WALK_1 | R            | Spine        | Obliq           | Max                | RMTLH   |         5.27125     |
# | 2254 | C0324_SPL_PST03_WALK_1 | R            | Spine        | Obliq           | Min                | RMTLH   |         1.51435     |
# | 2255 | C0324_SPL_PST03_WALK_1 | R            | Spine        | Obliq           | ROM                | RMTLH   |         3.7569      |
# | 2256 | C0324_SPL_PST03_WALK_1 | R            | Spine        | Rot             | Max                | RMTLH   |         1.40722     |
# | 2257 | C0324_SPL_PST03_WALK_1 | R            | Spine        | Rot             | Min                | RMTLH   |        -4.35643     |
# | 2258 | C0324_SPL_PST03_WALK_1 | R            | Spine        | Rot             | ROM                | RMTLH   |         5.76365     |
# | 2259 | C0324_SPL_PST03_WALK_1 | L            | Spine        | Flex            | Max                | RMTLH   |        -3.91389     |
# | 2260 | C0324_SPL_PST03_WALK_1 | L            | Spine        | Flex            | Min                | RMTLH   |        -5.90746     |
# | 2261 | C0324_SPL_PST03_WALK_1 | L            | Spine        | Flex            | ROM                | RMTLH   |         1.99357     |
# | 2262 | C0324_SPL_PST03_WALK_1 | L            | Spine        | Obliq           | Max                | RMTLH   |        -1.51435     |
# | 2263 | C0324_SPL_PST03_WALK_1 | L            | Spine        | Obliq           | Min                | RMTLH   |        -5.27125     |
# | 2264 | C0324_SPL_PST03_WALK_1 | L            | Spine        | Obliq           | ROM                | RMTLH   |         3.7569      |
# | 2265 | C0324_SPL_PST03_WALK_1 | L            | Spine        | Rot             | Max                | RMTLH   |         4.35643     |
# | 2266 | C0324_SPL_PST03_WALK_1 | L            | Spine        | Rot             | Min                | RMTLH   |        -1.40722     |
# | 2267 | C0324_SPL_PST03_WALK_1 | L            | Spine        | Rot             | ROM                | RMTLH   |         5.76365     |
# | 2268 | C0324_SPL_PST03_WALK_1 | L            | Shoulder     | Flex            | Max                | RMTLH   |       -10.9078      |
# | 2269 | C0324_SPL_PST03_WALK_1 | L            | Shoulder     | Flex            | Min                | RMTLH   |       -20.186       |
# | 2270 | C0324_SPL_PST03_WALK_1 | L            | Shoulder     | Flex            | ROM                | RMTLH   |         9.2782      |
# | 2271 | C0324_SPL_PST03_WALK_1 | L            | Shoulder     | Add             | Max                | RMTLH   |        21.3725      |
# | 2272 | C0324_SPL_PST03_WALK_1 | L            | Shoulder     | Add             | Min                | RMTLH   |        19.8758      |
# | 2273 | C0324_SPL_PST03_WALK_1 | L            | Shoulder     | Add             | ROM                | RMTLH   |         1.4967      |
# | 2274 | C0324_SPL_PST03_WALK_1 | L            | Shoulder     | Rot             | Max                | RMTLH   |        35.6258      |
# | 2275 | C0324_SPL_PST03_WALK_1 | L            | Shoulder     | Rot             | Min                | RMTLH   |        31.4054      |
# | 2276 | C0324_SPL_PST03_WALK_1 | L            | Shoulder     | Rot             | ROM                | RMTLH   |         4.2204      |
# | 2277 | C0324_SPL_PST03_WALK_1 | L            | Elbow        | Flex            | Max                | RMTLH   |        33.7823      |
# | 2278 | C0324_SPL_PST03_WALK_1 | L            | Elbow        | Flex            | Min                | RMTLH   |        32.364       |
# | 2279 | C0324_SPL_PST03_WALK_1 | L            | Elbow        | Flex            | ROM                | RMTLH   |         1.4183      |
# | 2280 | C0324_SPL_PST03_WALK_1 | L            | Elbow        | Add             | Max                | RMTLH   |         3.18055e-15 |
# | 2281 | C0324_SPL_PST03_WALK_1 | L            | Elbow        | Add             | Min                | RMTLH   |        -2.78299e-15 |
# | 2282 | C0324_SPL_PST03_WALK_1 | L            | Elbow        | Add             | ROM                | RMTLH   |         5.96354e-15 |
# | 2283 | C0324_SPL_PST03_WALK_1 | L            | Elbow        | Rot             | Max                | RMTLH   |         4.77083e-12 |
# | 2284 | C0324_SPL_PST03_WALK_1 | L            | Elbow        | Rot             | Min                | RMTLH   |        -5.42603e-12 |
# | 2285 | C0324_SPL_PST03_WALK_1 | L            | Elbow        | Rot             | ROM                | RMTLH   |         1.01969e-11 |
# | 2286 | C0324_SPL_PST03_WALK_1 | L            | Wrist        | Flex            | Max                | RMTLH   |        -6.18187     |
# | 2287 | C0324_SPL_PST03_WALK_1 | L            | Wrist        | Flex            | Min                | RMTLH   |        -9.27497     |
# | 2288 | C0324_SPL_PST03_WALK_1 | L            | Wrist        | Flex            | ROM                | RMTLH   |         3.0931      |
# | 2289 | C0324_SPL_PST03_WALK_1 | L            | Wrist        | Add             | Max                | RMTLH   |         7.40711     |
# | 2290 | C0324_SPL_PST03_WALK_1 | L            | Wrist        | Add             | Min                | RMTLH   |         5.50084     |
# | 2291 | C0324_SPL_PST03_WALK_1 | L            | Wrist        | Add             | ROM                | RMTLH   |         1.90627     |
# | 2292 | C0324_SPL_PST03_WALK_1 | L            | Wrist        | Rot             | Max                | RMTLH   |       108.366       |
# | 2293 | C0324_SPL_PST03_WALK_1 | L            | Wrist        | Rot             | Min                | RMTLH   |       101.602       |
# | 2294 | C0324_SPL_PST03_WALK_1 | L            | Wrist        | Rot             | ROM                | RMTLH   |         6.764       |
# | 2295 | C0324_SPL_PST03_WALK_1 | R            | Shoulder     | Flex            | Max                | RMTLH   |        -1.19998     |
# | 2296 | C0324_SPL_PST03_WALK_1 | R            | Shoulder     | Flex            | Min                | RMTLH   |       -10.4559      |
# | 2297 | C0324_SPL_PST03_WALK_1 | R            | Shoulder     | Flex            | ROM                | RMTLH   |         9.25592     |
# | 2298 | C0324_SPL_PST03_WALK_1 | R            | Shoulder     | Add             | Max                | RMTLH   |        26.0491      |
# | 2299 | C0324_SPL_PST03_WALK_1 | R            | Shoulder     | Add             | Min                | RMTLH   |        23.4232      |
# | 2300 | C0324_SPL_PST03_WALK_1 | R            | Shoulder     | Add             | ROM                | RMTLH   |         2.6259      |
# | 2301 | C0324_SPL_PST03_WALK_1 | R            | Shoulder     | Rot             | Max                | RMTLH   |        27.8212      |
# | 2302 | C0324_SPL_PST03_WALK_1 | R            | Shoulder     | Rot             | Min                | RMTLH   |        18.7035      |
# | 2303 | C0324_SPL_PST03_WALK_1 | R            | Shoulder     | Rot             | ROM                | RMTLH   |         9.1177      |
# | 2304 | C0324_SPL_PST03_WALK_1 | R            | Elbow        | Flex            | Max                | RMTLH   |        42.7098      |
# | 2305 | C0324_SPL_PST03_WALK_1 | R            | Elbow        | Flex            | Min                | RMTLH   |        36.2026      |
# | 2306 | C0324_SPL_PST03_WALK_1 | R            | Elbow        | Flex            | ROM                | RMTLH   |         6.5072      |
# | 2307 | C0324_SPL_PST03_WALK_1 | R            | Elbow        | Add             | Max                | RMTLH   |         3.18055e-15 |
# | 2308 | C0324_SPL_PST03_WALK_1 | R            | Elbow        | Add             | Min                | RMTLH   |        -3.97569e-15 |
# | 2309 | C0324_SPL_PST03_WALK_1 | R            | Elbow        | Add             | ROM                | RMTLH   |         7.15624e-15 |
# | 2310 | C0324_SPL_PST03_WALK_1 | R            | Elbow        | Rot             | Max                | RMTLH   |         4.80582e-12 |
# | 2311 | C0324_SPL_PST03_WALK_1 | R            | Elbow        | Rot             | Min                | RMTLH   |        -3.85483e-12 |
# | 2312 | C0324_SPL_PST03_WALK_1 | R            | Elbow        | Rot             | ROM                | RMTLH   |         8.66065e-12 |
# | 2313 | C0324_SPL_PST03_WALK_1 | R            | Wrist        | Flex            | Max                | RMTLH   |        -4.75326     |
# | 2314 | C0324_SPL_PST03_WALK_1 | R            | Wrist        | Flex            | Min                | RMTLH   |        -9.3509      |
# | 2315 | C0324_SPL_PST03_WALK_1 | R            | Wrist        | Flex            | ROM                | RMTLH   |         4.59764     |
# | 2316 | C0324_SPL_PST03_WALK_1 | R            | Wrist        | Add             | Max                | RMTLH   |        12.5603      |
# | 2317 | C0324_SPL_PST03_WALK_1 | R            | Wrist        | Add             | Min                | RMTLH   |        11.102       |
# | 2318 | C0324_SPL_PST03_WALK_1 | R            | Wrist        | Add             | ROM                | RMTLH   |         1.4583      |
# | 2319 | C0324_SPL_PST03_WALK_1 | R            | Wrist        | Rot             | Max                | RMTLH   |       115.961       |
# | 2320 | C0324_SPL_PST03_WALK_1 | R            | Wrist        | Rot             | Min                | RMTLH   |       114.373       |
# | 2321 | C0324_SPL_PST03_WALK_1 | R            | Wrist        | Rot             | ROM                | RMTLH   |         1.588       |
# | 2322 | C0324_SPL_PST03_WALK_1 | R            | Thorax       | Flex            | Max                | RMTLH   |         2.08283     |
# | 2323 | C0324_SPL_PST03_WALK_1 | R            | Thorax       | Flex            | Min                | RMTLH   |        -0.0906441   |
# | 2324 | C0324_SPL_PST03_WALK_1 | R            | Thorax       | Flex            | ROM                | RMTLH   |         2.17347     |
# | 2325 | C0324_SPL_PST03_WALK_1 | R            | Thorax       | Obliq           | Max                | RMTLH   |        -1.56069     |
# | 2326 | C0324_SPL_PST03_WALK_1 | R            | Thorax       | Obliq           | Min                | RMTLH   |        -3.71111     |
# | 2327 | C0324_SPL_PST03_WALK_1 | R            | Thorax       | Obliq           | ROM                | RMTLH   |         2.15042     |
# | 2328 | C0324_SPL_PST03_WALK_1 | R            | Thorax       | Rot             | Max                | RMTLH   |         0.762304    |
# | 2329 | C0324_SPL_PST03_WALK_1 | R            | Thorax       | Rot             | Min                | RMTLH   |        -0.645703    |
# | 2330 | C0324_SPL_PST03_WALK_1 | R            | Thorax       | Rot             | ROM                | RMTLH   |         1.40801     |
# | 2331 | C0324_SPL_PST03_WALK_1 | L            | Thorax       | Flex            | Max                | RMTLH   |         2.08283     |
# | 2332 | C0324_SPL_PST03_WALK_1 | L            | Thorax       | Flex            | Min                | RMTLH   |        -0.0906441   |
# | 2333 | C0324_SPL_PST03_WALK_1 | L            | Thorax       | Flex            | ROM                | RMTLH   |         2.17347     |
# | 2334 | C0324_SPL_PST03_WALK_1 | L            | Thorax       | Obliq           | Max                | RMTLH   |         3.71111     |
# | 2335 | C0324_SPL_PST03_WALK_1 | L            | Thorax       | Obliq           | Min                | RMTLH   |         1.56069     |
# | 2336 | C0324_SPL_PST03_WALK_1 | L            | Thorax       | Obliq           | ROM                | RMTLH   |         2.15042     |
# | 2337 | C0324_SPL_PST03_WALK_1 | L            | Thorax       | Rot             | Max                | RMTLH   |         0.645703    |
# | 2338 | C0324_SPL_PST03_WALK_1 | L            | Thorax       | Rot             | Min                | RMTLH   |        -0.762304    |
# | 2339 | C0324_SPL_PST03_WALK_1 | L            | Thorax       | Rot             | ROM                | RMTLH   |         1.40801     |
# | 2340 | C0324_SPL_PST03_WALK_1 | R            | Head         | Flex            | Max                | RMTLH   |       -10.3878      |
# | 2341 | C0324_SPL_PST03_WALK_1 | R            | Head         | Flex            | Min                | RMTLH   |       -12.7063      |
# | 2342 | C0324_SPL_PST03_WALK_1 | R            | Head         | Flex            | ROM                | RMTLH   |         2.3185      |
# | 2343 | C0324_SPL_PST03_WALK_1 | R            | Head         | Obliq           | Max                | RMTLH   |        -2.4794      |
# | 2344 | C0324_SPL_PST03_WALK_1 | R            | Head         | Obliq           | Min                | RMTLH   |        -3.68349     |
# | 2345 | C0324_SPL_PST03_WALK_1 | R            | Head         | Obliq           | ROM                | RMTLH   |         1.20409     |
# | 2346 | C0324_SPL_PST03_WALK_1 | R            | Head         | Rot             | Max                | RMTLH   |        -5.4939      |
# | 2347 | C0324_SPL_PST03_WALK_1 | R            | Head         | Rot             | Min                | RMTLH   |        -5.98221     |
# | 2348 | C0324_SPL_PST03_WALK_1 | R            | Head         | Rot             | ROM                | RMTLH   |         0.48831     |
# | 2349 | C0324_SPL_PST03_WALK_1 | L            | Head         | Flex            | Max                | RMTLH   |       -10.3878      |
# | 2350 | C0324_SPL_PST03_WALK_1 | L            | Head         | Flex            | Min                | RMTLH   |       -12.7063      |
# | 2351 | C0324_SPL_PST03_WALK_1 | L            | Head         | Flex            | ROM                | RMTLH   |         2.3185      |
# | 2352 | C0324_SPL_PST03_WALK_1 | L            | Head         | Obliq           | Max                | RMTLH   |         3.68349     |
# | 2353 | C0324_SPL_PST03_WALK_1 | L            | Head         | Obliq           | Min                | RMTLH   |         2.4794      |
# | 2354 | C0324_SPL_PST03_WALK_1 | L            | Head         | Obliq           | ROM                | RMTLH   |         1.20409     |
# | 2355 | C0324_SPL_PST03_WALK_1 | L            | Head         | Rot             | Max                | RMTLH   |         5.98221     |
# | 2356 | C0324_SPL_PST03_WALK_1 | L            | Head         | Rot             | Min                | RMTLH   |         5.4939      |
# | 2357 | C0324_SPL_PST03_WALK_1 | L            | Head         | Rot             | ROM                | RMTLH   |         0.48831     |
# +------+------------------------+--------------+--------------+-----------------+--------------------+---------+---------------------+

# %%
m_df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 m_df.head()
#
# NameError: name 'm_df' is not defined
